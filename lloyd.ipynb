# %%
pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv(r'E:\data science\projects\Llyod_bank\Customer_Churn_Data_Large_customer_level.csv')

# %%
df.head()
# Out:
#    CustomerID  Age Gender MaritalStatus IncomeLevel  Total_Transactions  \
# 0           1   62      M        Single         Low                   1
# 1           2   65      M       Married         Low                   7
# 2           3   18      M        Single         Low                   6
# 3           4   21      M       Widowed         Low                   5
# 4           5   21      M      Divorced      Medium                   8
#
#    Total_Amount_Spent  Avg_Amount_Spent  Median_Amount_Spent  \
# 0              416.50         416.50000               416.50
# 1             1547.42         221.06000               199.73
# 2             1702.98         283.83000               293.79
# 3              917.29         183.45800               125.64
# 4             2001.49         250.18625               219.48
#
#   Last_Transaction_Date  ...  Complaint_Count  Unresolved_Count  \
# 0            2022-03-27  ...              0.0               0.0
# ...

# %%
df.describe()
# Out:
#         CustomerID          Age  Total_Transactions  Total_Amount_Spent  \
# count  1000.000000  1000.000000         1000.000000         1000.000000
# mean    500.500000    43.267000            5.054000         1267.074950
# std     288.819436    15.242311            2.603433          738.590013
# min       1.000000    18.000000            1.000000            9.800000
# 25%     250.750000    30.000000            3.000000          626.685000
# 50%     500.500000    43.000000            5.000000         1232.880000
# 75%     750.250000    56.000000            7.000000         1791.902500
# max    1000.000000    69.000000            9.000000         3386.040000
#
#        Avg_Amount_Spent  Median_Amount_Spent  Num_Product_Categories  \
# count       1000.000000          1000.000000             1000.000000
# mean         248.806511           249.181900                3.097000
# std           79.372766            95.787249                1.252661
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                       0
# Age                              0
# Gender                           0
# MaritalStatus                    0
# IncomeLevel                      0
# Total_Transactions               0
# Total_Amount_Spent               0
# Avg_Amount_Spent                 0
# Median_Amount_Spent              0
# Last_Transaction_Date            0
# Num_Product_Categories           0
# Total_Interactions               0
# Complaint_Count                  0
# Unresolved_Count                 0
# Last_Interaction_Date          332
# LastLoginDate                    0
# LoginFrequency                   0
# ServiceUsage                     0
# ChurnStatus                      0
# Days_Since_Last_Transaction      0
# Days_Since_Last_Interaction    332
# Days_Since_Last_Login            0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 22)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'MaritalStatus', 'IncomeLevel',
#        'Total_Transactions', 'Total_Amount_Spent', 'Avg_Amount_Spent',
#        'Median_Amount_Spent', 'Last_Transaction_Date',
#        'Num_Product_Categories', 'Total_Interactions', 'Complaint_Count',
#        'Unresolved_Count', 'Last_Interaction_Date', 'LastLoginDate',
#        'LoginFrequency', 'ServiceUsage', 'ChurnStatus',
#        'Days_Since_Last_Transaction', 'Days_Since_Last_Interaction',
#        'Days_Since_Last_Login'],
#       dtype='object')

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   1000 non-null   int64
#  1   Age                          1000 non-null   int64
#  2   Gender                       1000 non-null   object
#  3   MaritalStatus                1000 non-null   object
#  4   IncomeLevel                  1000 non-null   object
#  5   Total_Transactions           1000 non-null   int64
#  6   Total_Amount_Spent           1000 non-null   float64
#  7   Avg_Amount_Spent             1000 non-null   float64
#  8   Median_Amount_Spent          1000 non-null   float64
#  9   Last_Transaction_Date        1000 non-null   object
#  10  Num_Product_Categories       1000 non-null   int64
#  11  Total_Interactions           1000 non-null   float64
#  12  Complaint_Count              1000 non-null   float64
# ...

# %%
df['Last_Interaction_Date']
# Out:
# 0      2022-03-31
# 1      2022-03-17
# 2      2022-08-24
# 3      2022-11-18
# 4             NaN
#           ...
# 995           NaN
# 996           NaN
# 997           NaN
# 998           NaN
# 999           NaN
# Name: Last_Interaction_Date, Length: 1000, dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerID                       0
# Age                              0
# Gender                           0
# MaritalStatus                    0
# IncomeLevel                      0
# Total_Transactions               0
# Total_Amount_Spent               0
# Avg_Amount_Spent                 0
# Median_Amount_Spent              0
# Last_Transaction_Date            0
# Num_Product_Categories           0
# Total_Interactions               0
# Complaint_Count                  0
# Unresolved_Count                 0
# Last_Interaction_Date          332
# LastLoginDate                    0
# LoginFrequency                   0
# ServiceUsage                     0
# ChurnStatus                      0
# Days_Since_Last_Transaction      0
# Days_Since_Last_Interaction    332
# Days_Since_Last_Login            0
# dtype: int64

# %%
df.head()
# Out:
#    CustomerID  Age Gender MaritalStatus IncomeLevel  Total_Transactions  \
# 0           1   62      M        Single         Low                   1
# 1           2   65      M       Married         Low                   7
# 2           3   18      M        Single         Low                   6
# 3           4   21      M       Widowed         Low                   5
# 4           5   21      M      Divorced      Medium                   8
#
#    Total_Amount_Spent  Avg_Amount_Spent  Median_Amount_Spent  \
# 0              416.50         416.50000               416.50
# 1             1547.42         221.06000               199.73
# 2             1702.98         283.83000               293.79
# 3              917.29         183.45800               125.64
# 4             2001.49         250.18625               219.48
#
#   Last_Transaction_Date  ...  Complaint_Count  Unresolved_Count  \
# 0            2022-03-27  ...              0.0               0.0
# ...

# %%
df.shape
# Out:
# (1000, 22)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'MaritalStatus', 'IncomeLevel',
#        'Total_Transactions', 'Total_Amount_Spent', 'Avg_Amount_Spent',
#        'Median_Amount_Spent', 'Last_Transaction_Date',
#        'Num_Product_Categories', 'Total_Interactions', 'Complaint_Count',
#        'Unresolved_Count', 'Last_Interaction_Date', 'LastLoginDate',
#        'LoginFrequency', 'ServiceUsage', 'ChurnStatus',
#        'Days_Since_Last_Transaction', 'Days_Since_Last_Interaction',
#        'Days_Since_Last_Login'],
#       dtype='object')

# %%
# Only drop 'ChurnStatus' as it's the only column that exists in the current dataframe
df = df.drop(['ChurnStatus'], axis=1)

# %%
df.head(10)
# Out:
#    Age  Total_Transactions  Avg_Amount_Spent  Num_Product_Categories  \
# 0   62                   1        416.500000                       1
# 1   65                   7        221.060000                       4
# 2   18                   6        283.830000                       4
# 3   21                   5        183.458000                       4
# 4   21                   8        250.186250                       3
# 5   57                   5        232.858000                       4
# 6   27                   1         86.730000                       1
# 7   37                   7        292.411429                       4
# 8   39                   5        263.448000                       3
# 9   68                   7        199.622857                       4
#
#    Total_Interactions  Complaint_Count  Unresolved_Count  LoginFrequency  \
# 0                 1.0              0.0               0.0              34
# ...

# %%
# Get unique values from the dummy variables
print("Marital Status Categories:")
marital_columns = [col for col in df.columns if col.startswith('MaritalStatus_')]
print([col.replace('MaritalStatus_', '') for col in marital_columns])
# Out:
# Marital Status Categories:
# ['Married', 'Single', 'Widowed']

# %%
df = pd.get_dummies(df, drop_first=True).astype({col: int for col in df.select_dtypes(include='bool').columns})

# %%
df.head(10)
# Out:
#    Age  Total_Transactions  Avg_Amount_Spent  Num_Product_Categories  \
# 0   62                   1        416.500000                       1
# 1   65                   7        221.060000                       4
# 2   18                   6        283.830000                       4
# 3   21                   5        183.458000                       4
# 4   21                   8        250.186250                       3
# 5   57                   5        232.858000                       4
# 6   27                   1         86.730000                       1
# 7   37                   7        292.411429                       4
# 8   39                   5        263.448000                       3
# 9   68                   7        199.622857                       4
#
#    Total_Interactions  Complaint_Count  Unresolved_Count  LoginFrequency  \
# 0                 1.0              0.0               0.0              34
# ...

# %%
df.isnull().sum()
# Out:
# Age                            0
# Total_Transactions             0
# Avg_Amount_Spent               0
# Num_Product_Categories         0
# Total_Interactions             0
# Complaint_Count                0
# Unresolved_Count               0
# LoginFrequency                 0
# Days_Since_Last_Login          0
# Gender_M                       0
# MaritalStatus_Married          0
# MaritalStatus_Single           0
# MaritalStatus_Widowed          0
# IncomeLevel_Low                0
# IncomeLevel_Medium             0
# ServiceUsage_Online Banking    0
# ServiceUsage_Website           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          1000 non-null   int64
#  1   Total_Transactions           1000 non-null   int64
#  2   Avg_Amount_Spent             1000 non-null   float64
#  3   Num_Product_Categories       1000 non-null   int64
#  4   Total_Interactions           1000 non-null   float64
#  5   Complaint_Count              1000 non-null   float64
#  6   Unresolved_Count             1000 non-null   float64
#  7   LoginFrequency               1000 non-null   int64
#  8   Days_Since_Last_Login        1000 non-null   int64
#  9   Gender_M                     1000 non-null   int64
#  10  MaritalStatus_Married        1000 non-null   int64
#  11  MaritalStatus_Single         1000 non-null   int64
#  12  MaritalStatus_Widowed        1000 non-null   int64
# ...

# %%
df['IncomeLevel_Low'].value_counts()
# Out:
# IncomeLevel_Low
# 0    675
# 1    325
# Name: count, dtype: int64

# %%
sns.countplot(x='IncomeLevel_Medium', data=df)
# Out:
# <Axes: xlabel='IncomeLevel_Medium', ylabel='count'>

# %%
X=df.drop('IncomeLevel_Medium', axis=1)
Y=df['IncomeLevel_Medium']

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: IncomeLevel_Medium, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42, stratify=Y)

# %% [markdown]
# FEATURE SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.99719868, -0.02578018, -0.27271331, ..., -0.68796548,
#          1.34792485, -0.64881365],
#        [ 1.56878885,  1.12000571,  0.22408201, ...,  1.4535613 ,
#         -0.74188112,  1.54127461],
#        [-0.0102804 , -1.5534947 , -2.42160397, ..., -0.68796548,
#         -0.74188112,  1.54127461],
#        ...,
#        [ 0.45028147, -1.17156607, -0.27258786, ..., -0.68796548,
#          1.34792485, -0.64881365],
#        [-0.07607495,  1.12000571,  0.57389303, ...,  1.4535613 ,
#         -0.74188112,  1.54127461],
#        [-1.6551442 , -0.78963744, -2.06970729, ...,  1.4535613 ,
#          1.34792485, -0.64881365]], shape=(800, 16))

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()

# %%
log.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.635

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
precision_score(y_test, y_pred1)
# Out:
# 0.4393939393939394

# %%
recall_score(y_test, y_pred1)
# Out:
# 0.4461538461538462

# %%
f1_score(y_test, y_pred1)
# Out:
# 0.44274809160305345

# %%
# %pip install imbalanced-learn

from imblearn.over_sampling import SMOTE
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
X_res,Y_res = SMOTE().fit_resample(X, Y)

# %%
Y_res.value_counts()
# Out:
# IncomeLevel_Medium
# 0    674
# 1    674
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, Y_res, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.16623998, -0.80013949, -0.85107377, ..., -0.56235159,
#         -0.61810297,  1.68413151],
#        [ 0.36731179, -0.80013949, -0.0829706 , ..., -0.56235159,
#         -0.61810297,  1.68413151],
#        [ 1.30102738, -1.19328005,  0.45973377, ..., -0.56235159,
#         -0.61810297,  1.68413151],
#        ...,
#        [-1.23334352,  0.37928217,  0.03071315, ..., -0.56235159,
#         -0.61810297, -0.59377786],
#        [-0.89987367, -1.19328005, -1.48583152, ..., -0.56235159,
#         -0.61810297,  1.68413151],
#        [ 1.23433341,  0.77242272, -0.91486491, ..., -0.56235159,
#          1.61785341, -0.59377786]], shape=(1078, 16))

# %%
from sklearn.linear_model import LogisticRegression

# %%
log.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
ypred1 = log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, ypred1)
# Out:
# 0.7185185185185186

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# ensure predictions correspond to the current X_test / y_test
y_test_pred = log.predict(X_test)
precision_score(y_test, y_test_pred)
# Out:
# 0.673202614379085

# %%
recall_score(y_test, y_test_pred)
# Out:
# 0.7984496124031008

# %%
f1_score(y_test, y_test_pred)
# Out:
# 0.7304964539007093

# %%
f1_score(y_test, y_test_pred)
# Out:
# 0.7304964539007093

# %%
from sklearn import svm

# %%
svm = svm.SVC()

# %%
svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred2=svm.predict(X_test)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.7518518518518519

# %%
precision_score(y_test, y_pred2)
# Out:
# 0.7012987012987013

# %%
recall_score(y_test, y_pred2)
# Out:
# 0.8372093023255814

# %%
f1_score(y_test, y_pred2)
# Out:
# 0.7632508833922261

# %% [markdown]
# KNeighbors CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred3 = knn.predict(X_test)

# %%
accuracy_score(y_test, y_pred3)
# Out:
# 0.762962962962963

# %%
precision_score(y_test, y_pred3)
# Out:
# 0.7018633540372671

# %%
recall_score(y_test, y_pred3)
# Out:
# 0.875968992248062

# %%
f1_score(y_test, y_pred3)
# Out:
# 0.7793103448275862

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4 = dt.predict(X_test)

# %%
accuracy_score(y_test, y_pred4)
# Out:
# 0.7962962962962963

# %%
precision_score(y_test, y_pred4)
# Out:
# 0.7846153846153846

# %%
recall_score(y_test, y_pred4)
# Out:
# 0.7906976744186046

# %%
f1_score(y_test, y_pred4)
# Out:
# 0.7876447876447876

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred5= rf.predict(X_test)

# %%
accuracy_score(y_test, y_pred5)
# Out:
# 0.7814814814814814

# %%
precision_score(y_test, y_pred5)
# Out:
# 0.7430555555555556

# %%
recall_score(y_test, y_pred5)
# Out:
# 0.8294573643410853

# %%
f1_score(y_test, y_pred5)
# Out:
# 0.7838827838827839

# %% [markdown]
# GRADIENT BOOSTING CLASSIFIER

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred6= gbc.predict(X_test)

# %%
accuracy_score(y_test, y_pred6)
# Out:
# 0.7703703703703704

# %%
recall_score(y_test, y_pred6)
# Out:
# 0.8527131782945736

# %%
f1_score(y_test, y_pred6)
# Out:
# 0.7801418439716312

# %%
precision_score(y_test, y_pred6)
# Out:
# 0.7189542483660131

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'],
                           'Accuracy' : [accuracy_score(y_test, y_test_pred), accuracy_score(y_test, y_pred2), accuracy_score(y_test, y_pred3), accuracy_score(y_test, y_pred4), accuracy_score(y_test, y_pred5), accuracy_score(y_test, y_pred6)],
                   
                           })

# %%
final_data
# Out:
#   Models  Accuracy
# 0     LR  0.718519
# 1    SVC  0.751852
# 2    KNN  0.762963
# 3     DT  0.796296
# 4     RF  0.781481
# 5    GBC  0.770370

# %%
import seaborn as sns

# %%
 sns.barplot(x='Models', y='Accuracy', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='Accuracy'>

# %% [markdown]
# PRECISION

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'],
                           'Precision' : [precision_score(y_test, y_test_pred), precision_score(y_test, y_pred2), precision_score(y_test, y_pred3), precision_score(y_test, y_pred4), precision_score(y_test, y_pred5), precision_score(y_test, y_pred6)]})

# %%
final_data
# Out:
#   Models  Precision
# 0     LR   0.673203
# 1    SVC   0.701299
# 2    KNN   0.701863
# 3     DT   0.784615
# 4     RF   0.743056
# 5    GBC   0.718954

# %%
sns.barplot(x='Models', y='Precision', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='Precision'>

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'],
                           'Accuracy' : [accuracy_score(y_test, y_test_pred), accuracy_score(y_test, y_pred2), accuracy_score(y_test, y_pred3), accuracy_score(y_test, y_pred4), accuracy_score(y_test, y_pred5), accuracy_score(y_test, y_pred6)],
                            'Precision' : [precision_score(y_test, y_test_pred), precision_score(y_test, y_pred2), precision_score(y_test, y_pred3), precision_score(y_test, y_pred4), precision_score(y_test, y_pred5), precision_score(y_test, y_pred6)],
                            'f1_Score' : [f1_score(y_test, y_test_pred), f1_score(y_test, y_pred2), f1_score(y_test, y_pred3), f1_score(y_test, y_pred4), f1_score(y_test, y_pred5), f1_score(y_test, y_pred6)],
                            'Recall' : [recall_score(y_test, y_test_pred), recall_score(y_test, y_pred2), recall_score(y_test, y_pred3), recall_score(y_test, y_pred4), recall_score(y_test, y_pred5), recall_score(y_test, y_pred6)]
                          })

# %%
final_data
# Out:
#   Models  Accuracy  Precision  f1_Score    Recall
# 0     LR  0.718519   0.673203  0.730496  0.798450
# 1    SVC  0.751852   0.701299  0.763251  0.837209
# 2    KNN  0.762963   0.701863  0.779310  0.875969
# 3     DT  0.796296   0.784615  0.787645  0.790698
# 4     RF  0.781481   0.743056  0.783883  0.829457
# 5    GBC  0.770370   0.718954  0.780142  0.852713

# %% [markdown]
# ACCURACY

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'],
                           'Accuracy' : [accuracy_score(y_test, y_test_pred), accuracy_score(y_test, y_pred2), accuracy_score(y_test, y_pred3), accuracy_score(y_test, y_pred4), accuracy_score(y_test, y_pred5), accuracy_score(y_test, y_pred6)]
                            })

# %%
sns.barplot(x='Models', y='Accuracy', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='Accuracy'>

# %% [markdown]
# F1_SCORE

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'],
                           'F1_Score' : [f1_score(y_test,  y_test_pred), f1_score(y_test, y_pred2), f1_score(y_test, y_pred3), f1_score(y_test, y_pred4), f1_score(y_test, y_pred5), f1_score(y_test, y_pred6)],
                           
                            })

# %%
sns.barplot(x='Models', y='F1_Score', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='F1_Score'>

# %% [markdown]
# RECALL

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'],
                           'Recall' : [recall_score(y_test, y_test_pred), recall_score(y_test, y_pred2), recall_score(y_test, y_pred3), recall_score(y_test, y_pred4), recall_score(y_test, y_pred5), recall_score(y_test, y_pred6)]
                          })

# %%
sns.barplot(x='Models', y='Recall', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='Recall'>

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVC', 'KNN', 'DT', 'RF', 'GBC'],
                           'Accuracy' : [accuracy_score(y_test, y_test_pred), accuracy_score(y_test, y_pred2), accuracy_score(y_test, y_pred3), accuracy_score(y_test, y_pred4), accuracy_score(y_test, y_pred5), accuracy_score(y_test, y_pred6)],
                            'Precision' : [precision_score(y_test, y_test_pred), precision_score(y_test, y_pred2), precision_score(y_test, y_pred3), precision_score(y_test, y_pred4), precision_score(y_test, y_pred5), precision_score(y_test, y_pred6)],
                            'f1_Score' : [f1_score(y_test, y_test_pred), f1_score(y_test, y_pred2), f1_score(y_test, y_pred3), f1_score(y_test, y_pred4), f1_score(y_test, y_pred5), f1_score(y_test, y_pred6)],
                            'Recall' : [recall_score(y_test, y_test_pred), recall_score(y_test, y_pred2), recall_score(y_test, y_pred3), recall_score(y_test, y_pred4), recall_score(y_test, y_pred5), recall_score(y_test, y_pred6)]
                          })

# %%
final_data
# Out:
#   Models  Accuracy  Precision  f1_Score    Recall
# 0     LR  0.718519   0.673203  0.730496  0.798450
# 1    SVC  0.751852   0.701299  0.763251  0.837209
# 2    KNN  0.762963   0.701863  0.779310  0.875969
# 3     DT  0.796296   0.784615  0.787645  0.790698
# 4     RF  0.781481   0.743056  0.783883  0.829457
# 5    GBC  0.770370   0.718954  0.780142  0.852713

# %% [markdown]
# SAVE THE MODEL

# %%
X_res = sc.fit_transform(X_res)

# %%
rf.fit(X_res, Y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf,'rf_lloyd_churn_model.pkl')
# Out:
# ['rf_lloyd_churn_model.pkl']

# %%
model = joblib.load('rf_lloyd_churn_model.pkl')

# %%
df.columns
# Out:
# Index(['Age', 'Total_Transactions', 'Avg_Amount_Spent',
#        'Num_Product_Categories', 'Total_Interactions', 'Complaint_Count',
#        'Unresolved_Count', 'LoginFrequency', 'Days_Since_Last_Login',
#        'Gender_M', 'MaritalStatus_Married', 'MaritalStatus_Single',
#        'MaritalStatus_Widowed', 'IncomeLevel_Low', 'IncomeLevel_Medium',
#        'ServiceUsage_Online Banking', 'ServiceUsage_Website'],
#       dtype='object')

# %%
# Example input with 16 features in the correct order
# [Age, Total_Transactions, Avg_Amount_Spent, Num_Product_Categories, Total_Interactions, Complaint_Count, Unresolved_Count, LoginFrequency, Days_Since_Last_Login, Gender_M, MaritalStatus_Married, MaritalStatus_Single, MaritalStatus_Widowed, IncomeLevel_Low, ServiceUsage_Online Banking, ServiceUsage_Website]
input_features = [[18, 1, 0, 0, 1, 0, 0, 67, 1, 0, 1, 0, 0, 1, 7, 0]]
model.predict(input_features)
# Out:
# array([0])

# %%
model.predict([[45,1,0,0,1,0,0,3,2,1,0,1,0,0,0,0]])
# Out:
# array([1])

# %%
# X_train is a numpy array after scaling, it has no .columns.
# Use the original DataFrame `X` (or `df`) to print the feature names.
print(X.columns)
# Out:
# Index(['Age', 'Total_Transactions', 'Avg_Amount_Spent',
#        'Num_Product_Categories', 'Total_Interactions', 'Complaint_Count',
#        'Unresolved_Count', 'LoginFrequency', 'Days_Since_Last_Login',
#        'Gender_M', 'MaritalStatus_Married', 'MaritalStatus_Single',
#        'MaritalStatus_Widowed', 'IncomeLevel_Low',
#        'ServiceUsage_Online Banking', 'ServiceUsage_Website'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     Age  Total_Transactions  Avg_Amount_Spent  Num_Product_Categories  \
# 0    62                   1        416.500000                       1
# 1    65                   7        221.060000                       4
# 2    18                   6        283.830000                       4
# 3    21                   5        183.458000                       4
# 4    21                   8        250.186250                       3
# 5    57                   5        232.858000                       4
# 6    27                   1         86.730000                       1
# 7    37                   7        292.411429                       4
# 8    39                   5        263.448000                       3
# 9    68                   7        199.622857                       4
# 10   54                   5        346.766000                       2
# 11   41                   1         87.100000                       1
# ...

# %%
import joblib
model = joblib.load(r"E:\data science\projects\Llyod_bank\rf_lloyd_churn_model.pkl")
print(model.n_features_in_)
# Out:
# 16

# %%
print(X.columns.tolist())
# Out:
# ['Age', 'Total_Transactions', 'Avg_Amount_Spent', 'Num_Product_Categories', 'Total_Interactions', 'Complaint_Count', 'Unresolved_Count', 'LoginFrequency', 'Days_Since_Last_Login', 'Gender_M', 'MaritalStatus_Married', 'MaritalStatus_Single', 'MaritalStatus_Widowed', 'IncomeLevel_Low', 'ServiceUsage_Online Banking', 'ServiceUsage_Website']

# %%
print(model.n_features_in_)
print(X.columns.tolist())
# Out:
# 16
# ['Age', 'Total_Transactions', 'Avg_Amount_Spent', 'Num_Product_Categories', 'Total_Interactions', 'Complaint_Count', 'Unresolved_Count', 'LoginFrequency', 'Days_Since_Last_Login', 'Gender_M', 'MaritalStatus_Married', 'MaritalStatus_Single', 'MaritalStatus_Widowed', 'IncomeLevel_Low', 'ServiceUsage_Online Banking', 'ServiceUsage_Website']

# %%
df.to_csv(r"E:\data science\projects\Llyod_bank\cleaned_lloyd_data.csv", index=False)
